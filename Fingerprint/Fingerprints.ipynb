# %%
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="1" #model will be trained on GPU 1

# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline
from skimage.filters import threshold_otsu
import numpy as np
from glob import glob
import math

# !pip install matplotlib
# !pip install numpy
# !pip install opencv_python
# !pip install pillow
# !pip install scikit-image
# !pip install tk

# %%
# data = glob('../database/DB1_B*/*')
from google.colab import drive

# %%
# !pip install gdown
# !gdown https://drive.google.com/uc?id=1DNR3VUlfRgrHsdA11exbXqJ4H6wJ2Rcd

# %%
# !unzip "/content/database.zip"

# %%
data_directory = "/content/database/DB1_B"

# %%
def walk_through_dir(dir_path):
  for dirpath, dirnames, filenames in os.walk(dir_path):
    print(f"There are {len(dirnames)} directories and {len(filenames)} images in '{dirpath}'.")


walk_through_dir(data)
len(data)
# Out:
# There are 0 directories and 80 images in '/content/database/DB1_B/.'.
# 25

# %%
data_directory = "/content/database/DB1_B"
images = []

def read_images(data):
    for dirpath, dirnames, filenames in os.walk(data):
        for filename in filenames:
            image_path = os.path.join(dirpath, filename)
            img = cv2.imread(image_path)
            if img is not None:
                img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
                img = cv2.resize(img, (224, 224))
                images.append(img)
    return images

# Call the function to read and store images
images = read_images(data_directory)

# Now, the 'images' list should contain the image data
print(f"Total images loaded: {len(images)}")

# %% [markdown]
# # 1) Original Images
#
# ---

# %%
fig = plt.figure(figsize=(10, 10))

fig.add_subplot(1,3, 1)
plt.imshow(images[0])
plt.axis('off')
plt.title("First")
fig.add_subplot(1,3, 2)
plt.imshow(images[1])
plt.axis('off')
plt.title("Second")
fig.add_subplot(1,3,3)
plt.imshow(images[2])
plt.axis('off')
plt.title("Third")
# Out:
# Text(0.5, 1.0, 'Third')

# %% [markdown]
# # 2) Image enchancement
#
# ---
